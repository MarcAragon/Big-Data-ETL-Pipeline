# %%
import dlt
import pyarrow.parquet as pq
import fsspec
import toml #Esto para forzar que se lea de aqui

secrets_path = "./.dlt/secrets.toml"
secrets = toml.load(secrets_path)
# Define un recurso que lee datos de un parquet remoto
@dlt.resource(table_name="Users")
def my_df():
    parquet_url = "https://datasets-documentation.s3.eu-west-3.amazonaws.com/stackoverflow/parquet/users.parquet"
    with fsspec.open(parquet_url, mode="rb") as f:
        parquet_file = pq.ParquetFile(f)
        print('Extrayendo parquet')

        print(f"Total de filas: {parquet_file.metadata.num_rows}")
        print(f"Número de row groups: {parquet_file.num_row_groups}")

        for i, batch in enumerate(parquet_file.iter_batches()):
            print(f"Procesando batch {i + 1}...")

            df = batch.to_pandas()
            df = df.convert_dtypes()

            print(f"Batch {i + 1} con {len(df)} filas")

            yield df


# 🚀 Pipeline configurado con destino filesystem
# Las credenciales se leerán automáticamente desde `.dlt/secrets.toml`
pipeline = dlt.pipeline(
    pipeline_name="Bronze_MinIO",
    destination="filesystem",
    dataset_name="Users"
)

# Ejecutamos el pipeline
load_info = pipeline.run(
    my_df,
    loader_file_format="parquet",
    write_disposition="replace"
)
print(load_info)
# Out:
# subiendo parquet
# Extrayendo parquet
# 📊 Total de filas: 22484235
# 📦 Número de row groups: 27
# 🔄 Procesando batch 1...
# ✅ Batch 1 con 65536 filas
# 🔄 Procesando batch 2...
# ✅ Batch 2 con 65536 filas
# 🔄 Procesando batch 3...
# ✅ Batch 3 con 65536 filas
# 🔄 Procesando batch 4...
# ✅ Batch 4 con 65536 filas
# 🔄 Procesando batch 5...
# ✅ Batch 5 con 65536 filas
# 🔄 Procesando batch 6...
# ✅ Batch 6 con 65536 filas
# 🔄 Procesando batch 7...
# ✅ Batch 7 con 65536 filas
# 🔄 Procesando batch 8...
# ✅ Batch 8 con 65536 filas
# 🔄 Procesando batch 9...
# ✅ Batch 9 con 65536 filas
# 🔄 Procesando batch 10...
# ✅ Batch 10 con 65536 filas
# 🔄 Procesando batch 11...
# ✅ Batch 11 con 65536 filas
# 🔄 Procesando batch 12...
# ✅ Batch 12 con 65536 filas
# 🔄 Procesando batch 13...
# ✅ Batch 13 con 65536 filas
# 🔄 Procesando batch 14...
# ✅ Batch 14 con 65536 filas
# 🔄 Procesando batch 15...
# ✅ Batch 15 con 65536 filas
# 🔄 Procesando batch 16...
# ✅ Batch 16 con 65536 filas
# 🔄 Procesando batch 17...
# ✅ Batch 17 con 65536 filas
# 🔄 Procesando batch 18...
# ✅ Batch 18 con 65536 filas
# 🔄 Procesando batch 19...
# ✅ Batch 19 con 65536 filas
# 🔄 Procesando batch 20...
# ✅ Batch 20 con 65536 filas
# 🔄 Procesando batch 21...
# ✅ Batch 21 con 65536 filas
# 🔄 Procesando batch 22...
# ✅ Batch 22 con 65536 filas
