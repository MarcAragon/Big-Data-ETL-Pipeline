# %%
import dlt
import pyarrow.parquet as pq
import fsspec
import toml
import requests
import tempfile
import os
import time
import pandas as pd

secrets_path = "./.dlt/secrets.toml"
secrets = toml.load(secrets_path)

def read_parquet_in_batches(parquet_url, max_retries=5, delay=5, batch_size=50000):
    
    'Descarga parquet remoto con retries y lo lee en batches.'
    
    attempt = 0
    while attempt < max_retries:
        try:
            # Crear archivo temporal
            with tempfile.NamedTemporaryFile(delete=False, suffix=".parquet") as tmp_file:
                print(f"Descargando {parquet_url} ...")
                with requests.get(parquet_url, stream=True, timeout=60) as r:
                    r.raise_for_status()
                    for chunk in r.iter_content(chunk_size=8192):
                        tmp_file.write(chunk)
                tmp_file_path = tmp_file.name

            # Abrir parquet con pyarrow
            parquet_file = pq.ParquetFile(tmp_file_path)
            print('Extrayendo parquet')
            print(f"Total filas: {parquet_file.metadata.num_rows}")
            print(f"Row groups: {parquet_file.num_row_groups}")

            # Iterar batches
            for i, batch in enumerate(parquet_file.iter_batches(batch_size=batch_size)):
                print(f"Procesando batch {i + 1}...")
                df = batch.to_pandas().convert_dtypes()
                print(f"Batch {i + 1} con {len(df)} filas")
                yield df
            break

        except Exception as e:
            attempt += 1
            print(f"Error al descargar o leer parquet (intento {attempt}/{max_retries}): {e}")
            if attempt < max_retries:
                print(f"Reintentando en {delay} segundos...")
                time.sleep(delay)
            else:
                print("Se alcanzó el máximo de reintentos. Abortando.")
                raise
        finally:
            if 'tmp_file_path' in locals() and os.path.exists(tmp_file_path):
                os.remove(tmp_file_path)

@dlt.resource(table_name="Comments/2023")
def comments_2023():
    url = "https://datasets-documentation.s3.eu-west-3.amazonaws.com/stackoverflow/parquet/comments/2023.parquet"
    yield from read_parquet_in_batches(url)

@dlt.resource(table_name="Comments/2024")
def comments_2024():
    url = "https://datasets-documentation.s3.eu-west-3.amazonaws.com/stackoverflow/parquet/comments/2024.parquet"
    yield from read_parquet_in_batches(url)
    
pipeline = dlt.pipeline(
    pipeline_name="Bronze_MinIO_1",
    destination="filesystem",
    dataset_name="Bronze"  # carpeta raíz
)

load_info = pipeline.run(
    [comments_2023, comments_2024],
    loader_file_format="parquet",
    write_disposition="replace"
)

print(load_info)
# Out:
# Descargando https://datasets-documentation.s3.eu-west-3.amazonaws.com/stackoverflow/parquet/comments/2023.parquet ...
# Extrayendo parquet
# Total filas: 2950672
# Row groups: 3
# Procesando batch 1...
# Batch 1 con 50000 filas
# Descargando https://datasets-documentation.s3.eu-west-3.amazonaws.com/stackoverflow/parquet/comments/2024.parquet ...
# Extrayendo parquet
# Total filas: 580920
# Row groups: 1
# Procesando batch 1...
# Batch 1 con 50000 filas
# Procesando batch 2...
# Batch 2 con 50000 filas
# Procesando batch 2...
# Batch 2 con 50000 filas
# Procesando batch 3...
# Batch 3 con 50000 filas
# Procesando batch 3...
# Batch 3 con 50000 filas
# Procesando batch 4...
# Batch 4 con 50000 filas
# Procesando batch 4...
# Batch 4 con 50000 filas
# Procesando batch 5...
# Batch 5 con 50000 filas
# Procesando batch 5...
# Batch 5 con 50000 filas
# Procesando batch 6...
# Batch 6 con 50000 filas
# Procesando batch 6...
# Batch 6 con 50000 filas
# Procesando batch 7...
# Batch 7 con 50000 filas
# Procesando batch 7...
# Batch 7 con 50000 filas
# Procesando batch 8...
# Batch 8 con 50000 filas
# Procesando batch 8...
# Batch 8 con 50000 filas
# Procesando batch 9...
# Batch 9 con 50000 filas
# Procesando batch 9...
# Batch 9 con 50000 filas
# Procesando batch 10...
# Batch 10 con 50000 filas
# Procesando batch 10...
# Batch 10 con 50000 filas
# Procesando batch 11...
# Batch 11 con 50000 filas
# Procesando batch 11...
# Batch 11 con 50000 filas
# Procesando batch 12...
# Batch 12 con 50000 filas
# Procesando batch 12...
# Batch 12 con 30920 filas
# Procesando batch 13...
# Batch 13 con 50000 filas
# Procesando batch 14...
# Batch 14 con 50000 filas
# Procesando batch 15...
# Batch 15 con 50000 filas
# Procesando batch 16...
# Batch 16 con 50000 filas
# Procesando batch 17...
# Batch 17 con 50000 filas
# Procesando batch 18...
# Batch 18 con 50000 filas
# Procesando batch 19...
# Batch 19 con 50000 filas
# Procesando batch 20...
# Batch 20 con 50000 filas
# Procesando batch 21...
# Batch 21 con 50000 filas
# Procesando batch 22...
# Batch 22 con 50000 filas
# Procesando batch 23...
# Batch 23 con 50000 filas
# Procesando batch 24...
# Batch 24 con 50000 filas
# Procesando batch 25...
# Batch 25 con 50000 filas
# Procesando batch 26...
# Batch 26 con 50000 filas
# Procesando batch 27...
# Batch 27 con 50000 filas
# Procesando batch 28...
# Batch 28 con 50000 filas
# Procesando batch 29...
# Batch 29 con 50000 filas
# Procesando batch 30...
# Batch 30 con 50000 filas
# Procesando batch 31...
# Batch 31 con 50000 filas
# Procesando batch 32...
# Batch 32 con 50000 filas
# Procesando batch 33...
# Batch 33 con 50000 filas
# Procesando batch 34...
# Batch 34 con 50000 filas
# Procesando batch 35...
# Batch 35 con 50000 filas
# Procesando batch 36...
# Batch 36 con 50000 filas
# Procesando batch 37...
# Batch 37 con 50000 filas
# Procesando batch 38...
# Batch 38 con 50000 filas
# Procesando batch 39...
# Batch 39 con 50000 filas
# Procesando batch 40...
# Batch 40 con 50000 filas
# Procesando batch 41...
# Batch 41 con 50000 filas
# Procesando batch 42...
# Batch 42 con 50000 filas
# Procesando batch 43...
# Batch 43 con 50000 filas
# Procesando batch 44...
# Batch 44 con 50000 filas
# Procesando batch 45...
# Batch 45 con 50000 filas
# Procesando batch 46...
# Batch 46 con 50000 filas
# Procesando batch 47...
# Batch 47 con 50000 filas
# Procesando batch 48...
# Batch 48 con 50000 filas
# Procesando batch 49...
# Batch 49 con 50000 filas
# Procesando batch 50...
# Batch 50 con 50000 filas
# Procesando batch 51...
# Batch 51 con 50000 filas
# Procesando batch 52...
# Batch 52 con 50000 filas
# Procesando batch 53...
# Batch 53 con 50000 filas
# Procesando batch 54...
# Batch 54 con 50000 filas
# Procesando batch 55...
# Batch 55 con 50000 filas
# Procesando batch 56...
# Batch 56 con 50000 filas
# Procesando batch 57...
# Batch 57 con 50000 filas
# Procesando batch 58...
# Batch 58 con 50000 filas
# Procesando batch 59...
# Batch 59 con 50000 filas
# Procesando batch 60...
# Batch 60 con 672 filas
# Pipeline Bronze_MinIO_1 load step completed in 19.64 seconds
# 1 load package(s) were loaded to destination filesystem and into dataset bronze
# The filesystem destination used s3://proyecto2 location to store data
# Load package 1774918555.7865863 is LOADED and contains no failed jobs

# %%
@dlt.resource(table_name="Posts/2023")
def posts_2023():
    url = "https://datasets-documentation.s3.eu-west-3.amazonaws.com/stackoverflow/parquet/posts/2023.parquet"
    yield from read_parquet_in_batches(url)

@dlt.resource(table_name="Posts/2024")
def posts_2024():
    url = "https://datasets-documentation.s3.eu-west-3.amazonaws.com/stackoverflow/parquet/posts/2024.parquet"
    yield from read_parquet_in_batches(url)

pipeline = dlt.pipeline(
    pipeline_name="Bronze_MinIO_2",
    destination="filesystem",
    dataset_name="Bronze"  # carpeta raíz
)

load_info = pipeline.run(
    [posts_2023, posts_2024],
    loader_file_format="parquet",
    write_disposition="replace"
)

print(load_info)
# Out:
# Descargando https://datasets-documentation.s3.eu-west-3.amazonaws.com/stackoverflow/parquet/posts/2023.parquet ...
# Extrayendo parquet
# Total filas: 2001772
# Row groups: 7
# Procesando batch 1...
# Batch 1 con 50000 filas
# Descargando https://datasets-documentation.s3.eu-west-3.amazonaws.com/stackoverflow/parquet/posts/2024.parquet ...
# Extrayendo parquet
# Total filas: 385533
# Row groups: 2
# Procesando batch 1...
# Batch 1 con 50000 filas
# Procesando batch 2...
# Batch 2 con 50000 filas
# Procesando batch 2...
# Batch 2 con 50000 filas
# Procesando batch 3...
# Batch 3 con 50000 filas
# Procesando batch 3...
# Batch 3 con 50000 filas
# Procesando batch 4...
# Batch 4 con 50000 filas
# Procesando batch 4...
# Batch 4 con 50000 filas
# Procesando batch 5...
# Batch 5 con 50000 filas
# Procesando batch 5...
# Batch 5 con 50000 filas
# Procesando batch 6...
# Batch 6 con 50000 filas
# Procesando batch 6...
# Batch 6 con 50000 filas
# Procesando batch 7...
# Batch 7 con 50000 filas
# Procesando batch 7...
# Batch 7 con 50000 filas
# Procesando batch 8...
# Batch 8 con 50000 filas
# Procesando batch 8...
# Batch 8 con 35533 filas
# Procesando batch 9...
# Batch 9 con 50000 filas
# Procesando batch 10...
# Batch 10 con 50000 filas
# Procesando batch 11...
# Batch 11 con 50000 filas
# Procesando batch 12...
# Batch 12 con 50000 filas
# Procesando batch 13...
# Batch 13 con 50000 filas
# Procesando batch 14...
# Batch 14 con 50000 filas
# Procesando batch 15...
# Batch 15 con 50000 filas
# Procesando batch 16...
# Batch 16 con 50000 filas
# Procesando batch 17...
# Batch 17 con 50000 filas
# Procesando batch 18...
# Batch 18 con 50000 filas
# Procesando batch 19...
# Batch 19 con 50000 filas
# Procesando batch 20...
# Batch 20 con 50000 filas
# Procesando batch 21...
# Batch 21 con 50000 filas
# Procesando batch 22...
# Batch 22 con 50000 filas
# Procesando batch 23...
# Batch 23 con 50000 filas
# Procesando batch 24...
# Batch 24 con 50000 filas
# Procesando batch 25...
# Batch 25 con 50000 filas
# Procesando batch 26...
# Batch 26 con 50000 filas
# Procesando batch 27...
# Batch 27 con 50000 filas
# Procesando batch 28...
# Batch 28 con 50000 filas
# Procesando batch 29...
# Batch 29 con 50000 filas
# Procesando batch 30...
# Batch 30 con 50000 filas
# Procesando batch 31...
# Batch 31 con 50000 filas
# Procesando batch 32...
# Batch 32 con 50000 filas
# Procesando batch 33...
# Batch 33 con 50000 filas
# Procesando batch 34...
# Batch 34 con 50000 filas
# Procesando batch 35...
# Batch 35 con 50000 filas
# Procesando batch 36...
# Batch 36 con 50000 filas
# Procesando batch 37...
# Batch 37 con 50000 filas
# Procesando batch 38...
# Batch 38 con 50000 filas
# Procesando batch 39...
# Batch 39 con 50000 filas
# Procesando batch 40...
# Batch 40 con 50000 filas
# Procesando batch 41...
# Batch 41 con 1772 filas
# Pipeline Bronze_MinIO_2 load step completed in 39.23 seconds
# 1 load package(s) were loaded to destination filesystem and into dataset bronze
# The filesystem destination used s3://proyecto2 location to store data
# Load package 1774918638.6598768 is LOADED and contains no failed jobs

# %%
@dlt.resource(table_name="Users")
def users():
    url = "https://datasets-documentation.s3.eu-west-3.amazonaws.com/stackoverflow/parquet/users.parquet"
    yield from read_parquet_in_batches(url)

pipeline = dlt.pipeline(
    pipeline_name="Bronze_MinIO_3",
    destination="filesystem",
    dataset_name="Bronze"  # carpeta raíz
)

load_info = pipeline.run(
    [users],
    loader_file_format="parquet",
    write_disposition="replace"
)

print(load_info)
# Out:
# Descargando https://datasets-documentation.s3.eu-west-3.amazonaws.com/stackoverflow/parquet/users.parquet ...
# Extrayendo parquet
# Total filas: 22484235
# Row groups: 27
# Procesando batch 1...
# Batch 1 con 50000 filas
# Procesando batch 2...
# Batch 2 con 50000 filas
# Procesando batch 3...
# Batch 3 con 50000 filas
# Procesando batch 4...
# Batch 4 con 50000 filas
# Procesando batch 5...
# Batch 5 con 50000 filas
# Procesando batch 6...
# Batch 6 con 50000 filas
# Procesando batch 7...
# Batch 7 con 50000 filas
# Procesando batch 8...
# Batch 8 con 50000 filas
# Procesando batch 9...
# Batch 9 con 50000 filas
# Procesando batch 10...
# Batch 10 con 50000 filas
# Procesando batch 11...
# Batch 11 con 50000 filas
# Procesando batch 12...
# Batch 12 con 50000 filas
# Procesando batch 13...
# Batch 13 con 50000 filas
# Procesando batch 14...
# Batch 14 con 50000 filas
# Procesando batch 15...
# Batch 15 con 50000 filas
# Procesando batch 16...
# Batch 16 con 50000 filas
# Procesando batch 17...
# Batch 17 con 50000 filas
# Procesando batch 18...
# Batch 18 con 50000 filas
# Procesando batch 19...
# Batch 19 con 50000 filas
# Procesando batch 20...
# Batch 20 con 50000 filas
# Procesando batch 21...
# Batch 21 con 50000 filas
# Procesando batch 22...
# Batch 22 con 50000 filas
# Procesando batch 23...
# Batch 23 con 50000 filas
# Procesando batch 24...
# Batch 24 con 50000 filas
# Procesando batch 25...
# Batch 25 con 50000 filas
# Procesando batch 26...
# Batch 26 con 50000 filas
# Procesando batch 27...
# Batch 27 con 50000 filas
# Procesando batch 28...
# Batch 28 con 50000 filas
# Procesando batch 29...
# Batch 29 con 50000 filas
# Procesando batch 30...
# Batch 30 con 50000 filas
# Procesando batch 31...
# Batch 31 con 50000 filas
# Procesando batch 32...
# Batch 32 con 50000 filas
# Procesando batch 33...
# Batch 33 con 50000 filas
# Procesando batch 34...
# Batch 34 con 50000 filas
# Procesando batch 35...
# Batch 35 con 50000 filas
# Procesando batch 36...
# Batch 36 con 50000 filas
# Procesando batch 37...
# Batch 37 con 50000 filas
# Procesando batch 38...
# Batch 38 con 50000 filas
# Procesando batch 39...
# Batch 39 con 50000 filas
# Procesando batch 40...
# Batch 40 con 50000 filas
# Procesando batch 41...
# Batch 41 con 50000 filas
# Procesando batch 42...
# Batch 42 con 50000 filas
# Procesando batch 43...
# Batch 43 con 50000 filas
# Procesando batch 44...
# Batch 44 con 50000 filas
# Procesando batch 45...
# Batch 45 con 50000 filas
# Procesando batch 46...
# Batch 46 con 50000 filas
# Procesando batch 47...
# Batch 47 con 50000 filas
# Procesando batch 48...
# Batch 48 con 50000 filas
# Procesando batch 49...
# Batch 49 con 50000 filas
# Procesando batch 50...
# Batch 50 con 50000 filas
# Procesando batch 51...
# Batch 51 con 50000 filas
# Procesando batch 52...
# Batch 52 con 50000 filas
# Procesando batch 53...
# Batch 53 con 50000 filas
# Procesando batch 54...
# Batch 54 con 50000 filas
# Procesando batch 55...
# Batch 55 con 50000 filas
# Procesando batch 56...
# Batch 56 con 50000 filas
# Procesando batch 57...
# Batch 57 con 50000 filas
# Procesando batch 58...
# Batch 58 con 50000 filas
# Procesando batch 59...
# Batch 59 con 50000 filas
# Procesando batch 60...
# Batch 60 con 50000 filas
# Procesando batch 61...
# Batch 61 con 50000 filas
# Procesando batch 62...
# Batch 62 con 50000 filas
# Procesando batch 63...
# Batch 63 con 50000 filas
# Procesando batch 64...
# Batch 64 con 50000 filas
# Procesando batch 65...
# Batch 65 con 50000 filas
# Procesando batch 66...
# Batch 66 con 50000 filas
# Procesando batch 67...
# Batch 67 con 50000 filas
# Procesando batch 68...
# Batch 68 con 50000 filas
# Procesando batch 69...
# Batch 69 con 50000 filas
# Procesando batch 70...
# Batch 70 con 50000 filas
# Procesando batch 71...
# Batch 71 con 50000 filas
# Procesando batch 72...
# Batch 72 con 50000 filas
# Procesando batch 73...
# Batch 73 con 50000 filas
# Procesando batch 74...
# Batch 74 con 50000 filas
# Procesando batch 75...
# Batch 75 con 50000 filas
# Procesando batch 76...
# Batch 76 con 50000 filas
# Procesando batch 77...
# Batch 77 con 50000 filas
# Procesando batch 78...
# Batch 78 con 50000 filas
# Procesando batch 79...
# Batch 79 con 50000 filas
# Procesando batch 80...
# Batch 80 con 50000 filas
# Procesando batch 81...
# Batch 81 con 50000 filas
# Procesando batch 82...
# Batch 82 con 50000 filas
# Procesando batch 83...
# Batch 83 con 50000 filas
# Procesando batch 84...
# Batch 84 con 50000 filas
# Procesando batch 85...
# Batch 85 con 50000 filas
# Procesando batch 86...
# Batch 86 con 50000 filas
# Procesando batch 87...
# Batch 87 con 50000 filas
# Procesando batch 88...
# Batch 88 con 50000 filas
# Procesando batch 89...
# Batch 89 con 50000 filas
# Procesando batch 90...
# Batch 90 con 50000 filas
# Procesando batch 91...
# Batch 91 con 50000 filas
# Procesando batch 92...
# Batch 92 con 50000 filas
# Procesando batch 93...
# Batch 93 con 50000 filas
# Procesando batch 94...
# Batch 94 con 50000 filas
# Procesando batch 95...
# Batch 95 con 50000 filas
# Procesando batch 96...
# Batch 96 con 50000 filas
# Procesando batch 97...
# Batch 97 con 50000 filas
# Procesando batch 98...
# Batch 98 con 50000 filas
# Procesando batch 99...
# Batch 99 con 50000 filas
# Procesando batch 100...
# Batch 100 con 50000 filas
# Procesando batch 101...
# Batch 101 con 50000 filas
# Procesando batch 102...
# Batch 102 con 50000 filas
# Procesando batch 103...
# Batch 103 con 50000 filas
# Procesando batch 104...
# Batch 104 con 50000 filas
# Procesando batch 105...
# Batch 105 con 50000 filas
# Procesando batch 106...
# Batch 106 con 50000 filas
# Procesando batch 107...
# Batch 107 con 50000 filas
# Procesando batch 108...
# Batch 108 con 50000 filas
# Procesando batch 109...
# Batch 109 con 50000 filas
# Procesando batch 110...
# Batch 110 con 50000 filas
# Procesando batch 111...
# Batch 111 con 50000 filas
# Procesando batch 112...
# Batch 112 con 50000 filas
# Procesando batch 113...
# Batch 113 con 50000 filas
# Procesando batch 114...
# Batch 114 con 50000 filas
# Procesando batch 115...
# Batch 115 con 50000 filas
# Procesando batch 116...
# Batch 116 con 50000 filas
# Procesando batch 117...
# Batch 117 con 50000 filas
# Procesando batch 118...
# Batch 118 con 50000 filas
# Procesando batch 119...
# Batch 119 con 50000 filas
# Procesando batch 120...
# Batch 120 con 50000 filas
# Procesando batch 121...
# Batch 121 con 50000 filas
# Procesando batch 122...
# Batch 122 con 50000 filas
# Procesando batch 123...
# Batch 123 con 50000 filas
# Procesando batch 124...
# Batch 124 con 50000 filas
# Procesando batch 125...
# Batch 125 con 50000 filas
# Procesando batch 126...
# Batch 126 con 50000 filas
# Procesando batch 127...
# Batch 127 con 50000 filas
# Procesando batch 128...
# Batch 128 con 50000 filas
# Procesando batch 129...
# Batch 129 con 50000 filas
# Procesando batch 130...
# Batch 130 con 50000 filas
# Procesando batch 131...
# Batch 131 con 50000 filas
# Procesando batch 132...
# Batch 132 con 50000 filas
# Procesando batch 133...
# Batch 133 con 50000 filas
# Procesando batch 134...
# Batch 134 con 50000 filas
# Procesando batch 135...
# Batch 135 con 50000 filas
# Procesando batch 136...
# Batch 136 con 50000 filas
# Procesando batch 137...
# Batch 137 con 50000 filas
# Procesando batch 138...
# Batch 138 con 50000 filas
# Procesando batch 139...
# Batch 139 con 50000 filas
# Procesando batch 140...
# Batch 140 con 50000 filas
# Procesando batch 141...
# Batch 141 con 50000 filas
# Procesando batch 142...
# Batch 142 con 50000 filas
# Procesando batch 143...
# Batch 143 con 50000 filas
# Procesando batch 144...
# Batch 144 con 50000 filas
# Procesando batch 145...
# Batch 145 con 50000 filas
# Procesando batch 146...
# Batch 146 con 50000 filas
# Procesando batch 147...
# Batch 147 con 50000 filas
# Procesando batch 148...
# Batch 148 con 50000 filas
# Procesando batch 149...
# Batch 149 con 50000 filas
# Procesando batch 150...
# Batch 150 con 50000 filas
# Procesando batch 151...
# Batch 151 con 50000 filas
# Procesando batch 152...
# Batch 152 con 50000 filas
# Procesando batch 153...
# Batch 153 con 50000 filas
# Procesando batch 154...
# Batch 154 con 50000 filas
# Procesando batch 155...
# Batch 155 con 50000 filas
# Procesando batch 156...
# Batch 156 con 50000 filas
# Procesando batch 157...
# Batch 157 con 50000 filas
# Procesando batch 158...
# Batch 158 con 50000 filas
# Procesando batch 159...
# Batch 159 con 50000 filas
# Procesando batch 160...
# Batch 160 con 50000 filas
# Procesando batch 161...
# Batch 161 con 50000 filas
# Procesando batch 162...
# Batch 162 con 50000 filas
# Procesando batch 163...
# Batch 163 con 50000 filas
# Procesando batch 164...
# Batch 164 con 50000 filas
# Procesando batch 165...
# Batch 165 con 50000 filas
# Procesando batch 166...
# Batch 166 con 50000 filas
# Procesando batch 167...
# Batch 167 con 50000 filas
# Procesando batch 168...
# Batch 168 con 50000 filas
# Procesando batch 169...
# Batch 169 con 50000 filas
# Procesando batch 170...
# Batch 170 con 50000 filas
# Procesando batch 171...
# Batch 171 con 50000 filas
# Procesando batch 172...
# Batch 172 con 50000 filas
# Procesando batch 173...
# Batch 173 con 50000 filas
# Procesando batch 174...
# Batch 174 con 50000 filas
# Procesando batch 175...
# Batch 175 con 50000 filas
# Procesando batch 176...
# Batch 176 con 50000 filas
# Procesando batch 177...
# Batch 177 con 50000 filas
# Procesando batch 178...
# Batch 178 con 50000 filas
# Procesando batch 179...
# Batch 179 con 50000 filas
# Procesando batch 180...
# Batch 180 con 50000 filas
# Procesando batch 181...
# Batch 181 con 50000 filas
# Procesando batch 182...
# Batch 182 con 50000 filas
# Procesando batch 183...
# Batch 183 con 50000 filas
# Procesando batch 184...
# Batch 184 con 50000 filas
# Procesando batch 185...
# Batch 185 con 50000 filas
# Procesando batch 186...
# Batch 186 con 50000 filas
# Procesando batch 187...
# Batch 187 con 50000 filas
# Procesando batch 188...
# Batch 188 con 50000 filas
# Procesando batch 189...
# Batch 189 con 50000 filas
# Procesando batch 190...
# Batch 190 con 50000 filas
# Procesando batch 191...
# Batch 191 con 50000 filas
# Procesando batch 192...
# Batch 192 con 50000 filas
# Procesando batch 193...
# Batch 193 con 50000 filas
# Procesando batch 194...
# Batch 194 con 50000 filas
# Procesando batch 195...
# Batch 195 con 50000 filas
# Procesando batch 196...
# Batch 196 con 50000 filas
# Procesando batch 197...
# Batch 197 con 50000 filas
# Procesando batch 198...
# Batch 198 con 50000 filas
# Procesando batch 199...
# Batch 199 con 50000 filas
# Procesando batch 200...
# Batch 200 con 50000 filas
# Procesando batch 201...
# Batch 201 con 50000 filas
# Procesando batch 202...
# Batch 202 con 50000 filas
# Procesando batch 203...
# Batch 203 con 50000 filas
# Procesando batch 204...
# Batch 204 con 50000 filas
# Procesando batch 205...
# Batch 205 con 50000 filas
# Procesando batch 206...
# Batch 206 con 50000 filas
# Procesando batch 207...
# Batch 207 con 50000 filas
# Procesando batch 208...
# Batch 208 con 50000 filas
# Procesando batch 209...
# Batch 209 con 50000 filas
# Procesando batch 210...
# Batch 210 con 50000 filas
# Procesando batch 211...
# Batch 211 con 50000 filas
# Procesando batch 212...
# Batch 212 con 50000 filas
# Procesando batch 213...
# Batch 213 con 50000 filas
# Procesando batch 214...
# Batch 214 con 50000 filas
# Procesando batch 215...
# Batch 215 con 50000 filas
# Procesando batch 216...
# Batch 216 con 50000 filas
# Procesando batch 217...
# Batch 217 con 50000 filas
# Procesando batch 218...
# Batch 218 con 50000 filas
# Procesando batch 219...
# Batch 219 con 50000 filas
# Procesando batch 220...
# Batch 220 con 50000 filas
# Procesando batch 221...
# Batch 221 con 50000 filas
# Procesando batch 222...
# Batch 222 con 50000 filas
# Procesando batch 223...
# Batch 223 con 50000 filas
# Procesando batch 224...
# Batch 224 con 50000 filas
# Procesando batch 225...
# Batch 225 con 50000 filas
# Procesando batch 226...
# Batch 226 con 50000 filas
# Procesando batch 227...
# Batch 227 con 50000 filas
# Procesando batch 228...
# Batch 228 con 50000 filas
# Procesando batch 229...
# Batch 229 con 50000 filas
# Procesando batch 230...
# Batch 230 con 50000 filas
# Procesando batch 231...
# Batch 231 con 50000 filas
# Procesando batch 232...
# Batch 232 con 50000 filas
# Procesando batch 233...
# Batch 233 con 50000 filas
# Procesando batch 234...
# Batch 234 con 50000 filas
# Procesando batch 235...
# Batch 235 con 50000 filas
# Procesando batch 236...
# Batch 236 con 50000 filas
# Procesando batch 237...
# Batch 237 con 50000 filas
# Procesando batch 238...
# Batch 238 con 50000 filas
# Procesando batch 239...
# Batch 239 con 50000 filas
# Procesando batch 240...
# Batch 240 con 50000 filas
# Procesando batch 241...
# Batch 241 con 50000 filas
# Procesando batch 242...
# Batch 242 con 50000 filas
# Procesando batch 243...
# Batch 243 con 50000 filas
# Procesando batch 244...
# Batch 244 con 50000 filas
# Procesando batch 245...
# Batch 245 con 50000 filas
# Procesando batch 246...
# Batch 246 con 50000 filas
# Procesando batch 247...
# Batch 247 con 50000 filas
# Procesando batch 248...
# Batch 248 con 50000 filas
# Procesando batch 249...
# Batch 249 con 50000 filas
# Procesando batch 250...
# Batch 250 con 50000 filas
# Procesando batch 251...
# Batch 251 con 50000 filas
# Procesando batch 252...
# Batch 252 con 50000 filas
# Procesando batch 253...
# Batch 253 con 50000 filas
# Procesando batch 254...
# Batch 254 con 50000 filas
# Procesando batch 255...
# Batch 255 con 50000 filas
# Procesando batch 256...
# Batch 256 con 50000 filas
# Procesando batch 257...
# Batch 257 con 50000 filas
# Procesando batch 258...
# Batch 258 con 50000 filas
# Procesando batch 259...
# Batch 259 con 50000 filas
# Procesando batch 260...
# Batch 260 con 50000 filas
# Procesando batch 261...
# Batch 261 con 50000 filas
# Procesando batch 262...
# Batch 262 con 50000 filas
# Procesando batch 263...
# Batch 263 con 50000 filas
# Procesando batch 264...
# Batch 264 con 50000 filas
# Procesando batch 265...
# Batch 265 con 50000 filas
# Procesando batch 266...
# Batch 266 con 50000 filas
# Procesando batch 267...
# Batch 267 con 50000 filas
# Procesando batch 268...
# Batch 268 con 50000 filas
# Procesando batch 269...
# Batch 269 con 50000 filas
# Procesando batch 270...
# Batch 270 con 50000 filas
# Procesando batch 271...
# Batch 271 con 50000 filas
# Procesando batch 272...
# Batch 272 con 50000 filas
# Procesando batch 273...
# Batch 273 con 50000 filas
# Procesando batch 274...
# Batch 274 con 50000 filas
# Procesando batch 275...
# Batch 275 con 50000 filas
# Procesando batch 276...
# Batch 276 con 50000 filas
# Procesando batch 277...
# Batch 277 con 50000 filas
# Procesando batch 278...
# Batch 278 con 50000 filas
# Procesando batch 279...
# Batch 279 con 50000 filas
# Procesando batch 280...
# Batch 280 con 50000 filas
# Procesando batch 281...
# Batch 281 con 50000 filas
# Procesando batch 282...
# Batch 282 con 50000 filas
# Procesando batch 283...
# Batch 283 con 50000 filas
# Procesando batch 284...
# Batch 284 con 50000 filas
# Procesando batch 285...
# Batch 285 con 50000 filas
# Procesando batch 286...
# Batch 286 con 50000 filas
# Procesando batch 287...
# Batch 287 con 50000 filas
# Procesando batch 288...
# Batch 288 con 50000 filas
# Procesando batch 289...
# Batch 289 con 50000 filas
# Procesando batch 290...
# Batch 290 con 50000 filas
# Procesando batch 291...
# Batch 291 con 50000 filas
# Procesando batch 292...
# Batch 292 con 50000 filas
# Procesando batch 293...
# Batch 293 con 50000 filas
# Procesando batch 294...
# Batch 294 con 50000 filas
# Procesando batch 295...
# Batch 295 con 50000 filas
# Procesando batch 296...
# Batch 296 con 50000 filas
# Procesando batch 297...
# Batch 297 con 50000 filas
# Procesando batch 298...
# Batch 298 con 50000 filas
# Procesando batch 299...
# Batch 299 con 50000 filas
# Procesando batch 300...
# Batch 300 con 50000 filas
# Procesando batch 301...
# Batch 301 con 50000 filas
# Procesando batch 302...
# Batch 302 con 50000 filas
# Procesando batch 303...
# Batch 303 con 50000 filas
# Procesando batch 304...
# Batch 304 con 50000 filas
# Procesando batch 305...
# Batch 305 con 50000 filas
# Procesando batch 306...
# Batch 306 con 50000 filas
# Procesando batch 307...
# Batch 307 con 50000 filas
# Procesando batch 308...
# Batch 308 con 50000 filas
# Procesando batch 309...
# Batch 309 con 50000 filas
# Procesando batch 310...
# Batch 310 con 50000 filas
# Procesando batch 311...
# Batch 311 con 50000 filas
# Procesando batch 312...
# Batch 312 con 50000 filas
# Procesando batch 313...
# Batch 313 con 50000 filas
# Procesando batch 314...
# Batch 314 con 50000 filas
# Procesando batch 315...
# Batch 315 con 50000 filas
# Procesando batch 316...
# Batch 316 con 50000 filas
# Procesando batch 317...
# Batch 317 con 50000 filas
# Procesando batch 318...
# Batch 318 con 50000 filas
# Procesando batch 319...
# Batch 319 con 50000 filas
# Procesando batch 320...
# Batch 320 con 50000 filas
# Procesando batch 321...
# Batch 321 con 50000 filas
# Procesando batch 322...
# Batch 322 con 50000 filas
# Procesando batch 323...
# Batch 323 con 50000 filas
# Procesando batch 324...
# Batch 324 con 50000 filas
# Procesando batch 325...
# Batch 325 con 50000 filas
# Procesando batch 326...
# Batch 326 con 50000 filas
# Procesando batch 327...
# Batch 327 con 50000 filas
# Procesando batch 328...
# Batch 328 con 50000 filas
# Procesando batch 329...
# Batch 329 con 50000 filas
# Procesando batch 330...
# Batch 330 con 50000 filas
# Procesando batch 331...
# Batch 331 con 50000 filas
# Procesando batch 332...
# Batch 332 con 50000 filas
# Procesando batch 333...
# Batch 333 con 50000 filas
# Procesando batch 334...
# Batch 334 con 50000 filas
# Procesando batch 335...
# Batch 335 con 50000 filas
# Procesando batch 336...
# Batch 336 con 50000 filas
# Procesando batch 337...
# Batch 337 con 50000 filas
# Procesando batch 338...
# Batch 338 con 50000 filas
# Procesando batch 339...
# Batch 339 con 50000 filas
# Procesando batch 340...
# Batch 340 con 50000 filas
# Procesando batch 341...
# Batch 341 con 50000 filas
# Procesando batch 342...
# Batch 342 con 50000 filas
# Procesando batch 343...
# Batch 343 con 50000 filas
# Procesando batch 344...
# Batch 344 con 50000 filas
# Procesando batch 345...
# Batch 345 con 50000 filas
# Procesando batch 346...
# Batch 346 con 50000 filas
# Procesando batch 347...
# Batch 347 con 50000 filas
# Procesando batch 348...
# Batch 348 con 50000 filas
# Procesando batch 349...
# Batch 349 con 50000 filas
# Procesando batch 350...
# Batch 350 con 50000 filas
# Procesando batch 351...
# Batch 351 con 50000 filas
# Procesando batch 352...
# Batch 352 con 50000 filas
# Procesando batch 353...
# Batch 353 con 50000 filas
# Procesando batch 354...
# Batch 354 con 50000 filas
# Procesando batch 355...
# Batch 355 con 50000 filas
# Procesando batch 356...
# Batch 356 con 50000 filas
# Procesando batch 357...
# Batch 357 con 50000 filas
# Procesando batch 358...
# Batch 358 con 50000 filas
# Procesando batch 359...
# Batch 359 con 50000 filas
# Procesando batch 360...
# Batch 360 con 50000 filas
# Procesando batch 361...
# Batch 361 con 50000 filas
# Procesando batch 362...
# Batch 362 con 50000 filas
# Procesando batch 363...
# Batch 363 con 50000 filas
# Procesando batch 364...
# Batch 364 con 50000 filas
# Procesando batch 365...
# Batch 365 con 50000 filas
# Procesando batch 366...
# Batch 366 con 50000 filas
# Procesando batch 367...
# Batch 367 con 50000 filas
# Procesando batch 368...
# Batch 368 con 50000 filas
# Procesando batch 369...
# Batch 369 con 50000 filas
# Procesando batch 370...
# Batch 370 con 50000 filas
# Procesando batch 371...
# Batch 371 con 50000 filas
# Procesando batch 372...
# Batch 372 con 50000 filas
# Procesando batch 373...
# Batch 373 con 50000 filas
# Procesando batch 374...
# Batch 374 con 50000 filas
# Procesando batch 375...
# Batch 375 con 50000 filas
# Procesando batch 376...
# Batch 376 con 50000 filas
# Procesando batch 377...
# Batch 377 con 50000 filas
# Procesando batch 378...
# Batch 378 con 50000 filas
# Procesando batch 379...
# Batch 379 con 50000 filas
# Procesando batch 380...
# Batch 380 con 50000 filas
# Procesando batch 381...
# Batch 381 con 50000 filas
# Procesando batch 382...
# Batch 382 con 50000 filas
# Procesando batch 383...
# Batch 383 con 50000 filas
# Procesando batch 384...
# Batch 384 con 50000 filas
# Procesando batch 385...
# Batch 385 con 50000 filas
# Procesando batch 386...
# Batch 386 con 50000 filas
# Procesando batch 387...
# Batch 387 con 50000 filas
# Procesando batch 388...
# Batch 388 con 50000 filas
# Procesando batch 389...
# Batch 389 con 50000 filas
# Procesando batch 390...
# Batch 390 con 50000 filas
# Procesando batch 391...
# Batch 391 con 50000 filas
# Procesando batch 392...
# Batch 392 con 50000 filas
# Procesando batch 393...
# Batch 393 con 50000 filas
# Procesando batch 394...
# Batch 394 con 50000 filas
# Procesando batch 395...
# Batch 395 con 50000 filas
# Procesando batch 396...
# Batch 396 con 50000 filas
# Procesando batch 397...
# Batch 397 con 50000 filas
# Procesando batch 398...
# Batch 398 con 50000 filas
# Procesando batch 399...
# Batch 399 con 50000 filas
# Procesando batch 400...
# Batch 400 con 50000 filas
# Procesando batch 401...
# Batch 401 con 50000 filas
# Procesando batch 402...
# Batch 402 con 50000 filas
# Procesando batch 403...
# Batch 403 con 50000 filas
# Procesando batch 404...
# Batch 404 con 50000 filas
# Procesando batch 405...
# Batch 405 con 50000 filas
# Procesando batch 406...
# Batch 406 con 50000 filas
# Procesando batch 407...
# Batch 407 con 50000 filas
# Procesando batch 408...
# Batch 408 con 50000 filas
# Procesando batch 409...
# Batch 409 con 50000 filas
# Procesando batch 410...
# Batch 410 con 50000 filas
# Procesando batch 411...
# Batch 411 con 50000 filas
# Procesando batch 412...
# Batch 412 con 50000 filas
# Procesando batch 413...
# Batch 413 con 50000 filas
# Procesando batch 414...
# Batch 414 con 50000 filas
# Procesando batch 415...
# Batch 415 con 50000 filas
# Procesando batch 416...
# Batch 416 con 50000 filas
# Procesando batch 417...
# Batch 417 con 50000 filas
# Procesando batch 418...
# Batch 418 con 50000 filas
# Procesando batch 419...
# Batch 419 con 50000 filas
# Procesando batch 420...
# Batch 420 con 50000 filas
# Procesando batch 421...
# Batch 421 con 50000 filas
# Procesando batch 422...
# Batch 422 con 50000 filas
# Procesando batch 423...
# Batch 423 con 50000 filas
# Procesando batch 424...
# Batch 424 con 50000 filas
# Procesando batch 425...
# Batch 425 con 50000 filas
# Procesando batch 426...
# Batch 426 con 50000 filas
# Procesando batch 427...
# Batch 427 con 50000 filas
# Procesando batch 428...
# Batch 428 con 50000 filas
# Procesando batch 429...
# Batch 429 con 50000 filas
# Procesando batch 430...
# Batch 430 con 50000 filas
# Procesando batch 431...
# Batch 431 con 50000 filas
# Procesando batch 432...
# Batch 432 con 50000 filas
# Procesando batch 433...
# Batch 433 con 50000 filas
# Procesando batch 434...
# Batch 434 con 50000 filas
# Procesando batch 435...
# Batch 435 con 50000 filas
# Procesando batch 436...
# Batch 436 con 50000 filas
# Procesando batch 437...
# Batch 437 con 50000 filas
# Procesando batch 438...
# Batch 438 con 50000 filas
# Procesando batch 439...
# Batch 439 con 50000 filas
# Procesando batch 440...
# Batch 440 con 50000 filas
# Procesando batch 441...
# Batch 441 con 50000 filas
# Procesando batch 442...
# Batch 442 con 50000 filas
# Procesando batch 443...
# Batch 443 con 50000 filas
# Procesando batch 444...
# Batch 444 con 50000 filas
# Procesando batch 445...
# Batch 445 con 50000 filas
# Procesando batch 446...
# Batch 446 con 50000 filas
# Procesando batch 447...
# Batch 447 con 50000 filas
# Procesando batch 448...
# Batch 448 con 50000 filas
# Procesando batch 449...
# Batch 449 con 50000 filas
# Procesando batch 450...
# Batch 450 con 34235 filas
# Pipeline Bronze_MinIO_3 load step completed in 28.21 seconds
# 1 load package(s) were loaded to destination filesystem and into dataset bronze
# The filesystem destination used s3://proyecto2 location to store data
# Load package 1774918922.266945 is LOADED and contains no failed jobs
