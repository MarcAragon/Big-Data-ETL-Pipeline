# %%
#2023
import dlt
import pyarrow.parquet as pq
import fsspec
import toml #Esto para forzar que se lea de aqui

secrets_path = "./.dlt/secrets.toml"
secrets = toml.load(secrets_path)
# Define un recurso que lee datos de un parquet remoto
@dlt.resource(table_name="Posts_2023")
def my_df():
    parquet_url = "https://datasets-documentation.s3.eu-west-3.amazonaws.com/stackoverflow/parquet/posts/2023.parquet"
    with fsspec.open(parquet_url, mode="rb") as f:
        parquet_file = pq.ParquetFile(f)
        print('Extrayendo parquet')

        print(f"Total de filas: {parquet_file.metadata.num_rows}")
        print(f"Número de row groups: {parquet_file.num_row_groups}")

        for i, batch in enumerate(parquet_file.iter_batches()):
            print(f"Procesando batch {i + 1}...")

            df = batch.to_pandas()
            df = df.convert_dtypes()

            print(f"Batch {i + 1} con {len(df)} filas")

            yield df


# 🚀 Pipeline configurado con destino filesystem
# Las credenciales se leerán automáticamente desde `.dlt/secrets.toml`
pipeline = dlt.pipeline(
    pipeline_name="Bronze_MinIO",
    destination="filesystem",
    dataset_name="Posts/2023"
)

# Ejecutamos el pipeline
load_info = pipeline.run(
    my_df,
    loader_file_format="parquet",
    write_disposition="replace"
)
print(load_info)
# Out:
# Extrayendo parquet
# Total de filas: 2001772
# Número de row groups: 7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 40
#      33 pipeline = dlt.pipeline(
#      34     pipeline_name="Bronze_MinIO",
#      35     destination="filesystem",
#      36     dataset_name="Posts/2023"
#      37 )
#      39 # Ejecutamos el pipeline
# ---> 40 load_info = pipeline.run(
#      41     my_df,
#      42     loader_file_format="parquet",
#      43     write_disposition="replace"
#      44 )
#      45 print(load_info)
#
# File /opt/conda/lib/python3.11/site-packages/dlt/pipeline/pipeline.py:226, in with_runtime_trace.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     223     if trace:
#     224         trace_step = start_trace_step(trace, cast(TPipelineStep, f.__name__), self)
# --> 226     step_info = f(self, *args, **kwargs)
#     227     return step_info
#     228 except Exception as ex:
#
# File /opt/conda/lib/python3.11/site-packages/dlt/pipeline/pipeline.py:275, in with_config_section.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     267 @wraps(f)
#     268 def _wrap(self: "Pipeline", *args: Any, **kwargs: Any) -> Any:
#     269     # add section context to the container to be used by all configuration without explicit sections resolution
#     270     with inject_section(
#     271         ConfigSectionContext(
#     272             pipeline_name=self.pipeline_name, sections=sections, merge_style=merge_func
#     273         )
#     274     ):
# --> 275         return f(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/dlt/pipeline/pipeline.py:735, in Pipeline.run(self, data, destination, staging, dataset_name, credentials, table_name, write_disposition, columns, primary_key, schema, loader_file_format, table_format, schema_contract, refresh)
#     733 # extract from the source
#     734 if data is not None:
# --> 735     self.extract(
#     736         data,
#     737         table_name=table_name,
#     738         write_disposition=write_disposition,
#     739         columns=columns,
#     740         primary_key=primary_key,
#     741         schema=schema,
#     742         table_format=table_format,
#     743         schema_contract=schema_contract,
#     744         refresh=refresh or self.refresh,
#     745     )
#     746     self.normalize(loader_file_format=loader_file_format)
#     747     return self.load(destination, dataset_name, credentials=credentials)
#
# File /opt/conda/lib/python3.11/site-packages/dlt/pipeline/pipeline.py:226, in with_runtime_trace.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     223     if trace:
#     224         trace_step = start_trace_step(trace, cast(TPipelineStep, f.__name__), self)
# --> 226     step_info = f(self, *args, **kwargs)
#     227     return step_info
#     228 except Exception as ex:
#
# File /opt/conda/lib/python3.11/site-packages/dlt/pipeline/pipeline.py:180, in with_schemas_sync.<locals>._wrap(self, *args, **kwargs)
#     178     self._schema_storage.commit_live_schema(name)
#     179 try:
# --> 180     rv = f(self, *args, **kwargs)
#     181 except Exception:
#     182     # because we committed live schema before calling f, we may safely
#     183     # drop all changes in live schemas
#     184     for name in list(self._schema_storage.live_schemas.keys()):
#
# File /opt/conda/lib/python3.11/site-packages/dlt/pipeline/pipeline.py:166, in with_state_sync.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     164 should_extract_state = may_extract_state and self.config.restore_from_destination
#     165 with self.managed_state(extract_state=should_extract_state):
# --> 166     return f(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/dlt/pipeline/pipeline.py:275, in with_config_section.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     267 @wraps(f)
#     268 def _wrap(self: "Pipeline", *args: Any, **kwargs: Any) -> Any:
#     269     # add section context to the container to be used by all configuration without explicit sections resolution
#     270     with inject_section(
#     271         ConfigSectionContext(
#     272             pipeline_name=self.pipeline_name, sections=sections, merge_style=merge_func
#     273         )
#     274     ):
# --> 275         return f(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/dlt/pipeline/pipeline.py:471, in Pipeline.extract(self, data, table_name, parent_table_name, write_disposition, columns, primary_key, schema, max_parallel_items, workers, table_format, schema_contract, refresh)
#     468     if source.exhausted:
#     469         raise SourceExhausted(source.name)
# --> 471     self._extract_source(
#     472         extract_step,
#     473         source,
#     474         max_parallel_items,
#     475         workers,
#     476         refresh=refresh or self.refresh,
#     477     )
#     479 # this will update state version hash so it will not be extracted again by with_state_sync
#     480 self._bump_version_and_extract_state(
#     481     self._container[StateInjectableContext].state,
#     482     self.config.restore_from_destination,
#     483     extract_step,
#     484 )
#
# File /opt/conda/lib/python3.11/site-packages/dlt/pipeline/pipeline.py:1239, in Pipeline._extract_source(self, extract, source, max_parallel_items, workers, refresh, load_package_state_update)
#    1236 source.schema.update_normalizers()
#    1238 # extract into pipeline schema
# -> 1239 load_id = extract.extract(
#    1240     source, max_parallel_items, workers, load_package_state_update=load_package_state_update
#    1241 )
#    1243 # update live schema but not update the store yet
#    1244 source.schema = self._schema_storage.set_live_schema(source.schema)
#
# File /opt/conda/lib/python3.11/site-packages/dlt/extract/extract.py:416, in Extract.extract(self, source, max_parallel_items, workers, load_package_state_update)
#     413                 if resource.write_disposition == "replace":
#     414                     reset_resource_state(resource.name)
# --> 416         self._extract_single_source(
#     417             load_id,
#     418             source,
#     419             max_parallel_items=max_parallel_items,
#     420             workers=workers,
#     421         )
#     422         commit_load_package_state()
#     423 return load_id
#
# File /opt/conda/lib/python3.11/site-packages/dlt/extract/extract.py:339, in Extract._extract_single_source(self, load_id, source, max_parallel_items, workers)
#     337 left_gens = total_gens = len(pipes._sources)
#     338 collector.update("Resources", 0, total_gens)
# --> 339 for pipe_item in pipes:
#     340     curr_gens = len(pipes._sources)
#     341     if left_gens > curr_gens:
#
# File /opt/conda/lib/python3.11/site-packages/dlt/extract/pipe_iterator.py:158, in PipeIterator.__next__(self)
#     154 pipe_item = self._futures_pool.resolve_next_future_no_wait()
#     156 if pipe_item is None:
#     157     # if none then take element from the newest source
# --> 158     pipe_item = self._get_source_item()
#     160 if pipe_item is None:
#     161     # Wait for some time for futures to resolve
#     162     try:
#
# File /opt/conda/lib/python3.11/site-packages/dlt/extract/pipe_iterator.py:274, in PipeIterator._get_source_item(self)
#     271 gen, step, pipe, meta = self._sources[self._current_source_index]
#     272 set_current_pipe_name(pipe.name)
# --> 274 pipe_item = next(gen)
#     275 if pipe_item is not None:
#     276     # full pipe item may be returned, this is used by ForkPipe step
#     277     # to redirect execution of an item to another pipe
#     278     # else
#     279     if not isinstance(pipe_item, ResolvablePipeItem):
#     280         # keep the item assigned step and pipe when creating resolvable item
#
# Cell In[2], line 20, in my_df()
#      17 print(f"Total de filas: {parquet_file.metadata.num_rows}")
#      18 print(f"Número de row groups: {parquet_file.num_row_groups}")
# ---> 20 for i, batch in enumerate(parquet_file.iter_batches()):
#      21     print(f"Procesando batch {i + 1}...")
#      23     df = batch.to_pandas()
#
# File /opt/conda/lib/python3.11/site-packages/pyarrow/_parquet.pyx:1579, in iter_batches()
#
# File /opt/conda/lib/python3.11/site-packages/pyarrow/error.pxi:88, in pyarrow.lib.check_status()
#
# File /opt/conda/lib/python3.11/site-packages/fsspec/implementations/http.py:596, in HTTPFile.read(self, length)
#     594 else:
#     595     length = min(self.size - self.loc, length)
# --> 596 return super().read(length)
#
# File /opt/conda/lib/python3.11/site-packages/fsspec/spec.py:1844, in AbstractBufferedFile.read(self, length)
#    1841 if length == 0:
#    1842     # don't even bother calling fetch
#    1843     return b""
# -> 1844 out = self.cache._fetch(self.loc, self.loc + length)
#    1845 self.loc += len(out)
#    1846 return out
#
# File /opt/conda/lib/python3.11/site-packages/fsspec/caching.py:436, in BytesCache._fetch(self, start, end)
#     434     pass
#     435 elif end - self.end > self.blocksize:
# --> 436     self.cache = self.fetcher(start, bend)
#     437     self.start = start
#     438 else:
#
# File /opt/conda/lib/python3.11/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/fsspec/asyn.py:91, in sync(loop, func, timeout, *args, **kwargs)
#      88 asyncio.run_coroutine_threadsafe(_runner(event, coro, result, timeout), loop)
#      89 while True:
#      90     # this loops allows thread to get interrupted
# ---> 91     if event.wait(1):
#      92         break
#      93     if timeout is not None:
#
# File /opt/conda/lib/python3.11/threading.py:622, in Event.wait(self, timeout)
#     620 signaled = self._flag
#     621 if not signaled:
# --> 622     signaled = self._cond.wait(timeout)
#     623 return signaled
#
# File /opt/conda/lib/python3.11/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
#2024
import dlt
import pyarrow.parquet as pq
import fsspec
import toml #Esto para forzar que se lea de aqui

secrets_path = "./.dlt/secrets.toml"
secrets = toml.load(secrets_path)
# Define un recurso que lee datos de un parquet remoto
@dlt.resource(table_name="Posts_2024")
def my_df():
    parquet_url = "https://datasets-documentation.s3.eu-west-3.amazonaws.com/stackoverflow/parquet/posts/2024.parquet"
    with fsspec.open(parquet_url, mode="rb") as f:
        parquet_file = pq.ParquetFile(f)
        print('Extrayendo parquet')

        print(f"Total de filas: {parquet_file.metadata.num_rows}")
        print(f"Número de row groups: {parquet_file.num_row_groups}")

        for i, batch in enumerate(parquet_file.iter_batches()):
            print(f"Procesando batch {i + 1}...")

            df = batch.to_pandas()
            df = df.convert_dtypes()

            print(f"Batch {i + 1} con {len(df)} filas")

            yield df


# 🚀 Pipeline configurado con destino filesystem
# Las credenciales se leerán automáticamente desde `.dlt/secrets.toml`
pipeline = dlt.pipeline(
    pipeline_name="Bronze_MinIO",
    destination="filesystem",
    dataset_name="Posts/2024"
)

# Ejecutamos el pipeline
load_info = pipeline.run(
    my_df,
    loader_file_format="parquet",
    write_disposition="replace"
)
print(load_info)
# Out:
# Extrayendo parquet
# Total de filas: 385533
# Número de row groups: 2
# Procesando batch 1...
# Batch 1 con 65536 filas
# Procesando batch 2...
# Batch 2 con 65536 filas
# Procesando batch 3...
# Batch 3 con 65536 filas
# Procesando batch 4...
# Batch 4 con 65536 filas
# Procesando batch 5...
# Batch 5 con 65536 filas
# Procesando batch 6...
# Batch 6 con 57853 filas
# Pipeline Bronze_MinIO load step completed in 4.00 seconds
# 1 load package(s) were loaded to destination filesystem and into dataset posts_2024
# The filesystem destination used s3://proyecto2/bronze location to store data
# Load package 1774823768.8459764 is LOADED and contains no failed jobs
