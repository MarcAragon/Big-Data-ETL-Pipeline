# %%
import json
from json import dumps
import pandas as pd
from pyspark.sql import SparkSession
from pyspark.sql.functions import lit, explode, from_json, col, current_date, regexp_replace, hex, expr, trim,coalesce, hash
from pyspark.sql.types import StringType, StructType, StructField, ArrayType, IntegerType
import datetime 
import requests
import urllib3
import matplotlib as mtl
from datetime import datetime,date
import pytz
import io
import glob
import os
import boto3
import pyspark

# %%
os.environ["AWS_REGION"] = "us-east-1"
CATALOG_URI = "http://nessie:19120/api/v1"  # Nessie Server URI
WAREHOUSE = "s3://proyecto2/silver"               # Minio Address to Write to
STORAGE_URI = "http://minio:9000"      # Minio IP address from docker inspect
AWS_ACCESS_KEY='admin'
AWS_SECRET_KEY='password'

# %%
conf = ( pyspark.SparkConf() .setAppName('combined_spark_app')
    .set("spark.driver.memory", "4g") \
    .set("spark.executor.memory", "4g") \
    .set("spark.sql.shuffle.partitions", "10") \
# Paquetes
.set('spark.jars.packages',
'org.postgresql:postgresql:42.7.3,'
#"org.apache.iceberg:iceberg-spark3-runtime:1.3.0,"
'org.apache.iceberg:iceberg-spark-runtime-3.4_2.12:1.5.0,'
'org.projectnessie.nessie-integrations:nessie-spark-extensions-3.4_2.12:0.77.1,'
'software.amazon.awssdk:bundle:2.24.8,'
'software.amazon.awssdk:url-connection-client:2.24.8,'
'org.apache.hadoop:hadoop-aws:3.2.0' )
# Extensiones
.set('spark.sql.extensions',
'org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions,'
'org.projectnessie.spark.extensions.NessieSparkSessionExtensions')
# Catálogo Nessie
.set('spark.sql.catalog.nessie', 'org.apache.iceberg.spark.SparkCatalog')
.set('spark.sql.catalog.nessie.uri', CATALOG_URI) .set('spark.sql.catalog.nessie.ref', 'main') .
set('spark.sql.catalog.nessie.authentication.type', 'NONE')
.set('spark.sql.catalog.nessie.catalog-impl', 'org.apache.iceberg.nessie.NessieCatalog')
# 🔥 IMPORTANTE: configuración S3 para Iceberg
.set('spark.sql.catalog.nessie.warehouse', WAREHOUSE)
.set('spark.sql.catalog.nessie.io-impl', 'org.apache.iceberg.aws.s3.S3FileIO')
.set('spark.sql.catalog.nessie.s3.endpoint', STORAGE_URI)
.set('spark.sql.catalog.nessie.s3.path-style-access', 'true')
.set('spark.sql.catalog.nessie.s3.access-key-id', AWS_ACCESS_KEY)
.set('spark.sql.catalog.nessie.s3.secret-access-key', AWS_SECRET_KEY)
# 🔥 Config S3A (Spark directo)
.set('spark.hadoop.fs.s3a.endpoint', STORAGE_URI)
.set('spark.hadoop.fs.s3a.access.key', AWS_ACCESS_KEY)
.set('spark.hadoop.fs.s3a.secret.key', AWS_SECRET_KEY)
.set('spark.hadoop.fs.s3a.path.style.access', 'true')
.set('spark.hadoop.fs.s3a.aws.credentials.provider', 'org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider')
.set('spark.hadoop.fs.s3a.connection.ssl.enabled', 'false') )

# %%
# Creación de la sesión de Spark
spark = SparkSession.builder.config(conf=conf).getOrCreate()
print("Spark Session Started")
# Out:
# Spark Session Started

# %%
df_users = spark.read.parquet("s3a://proyecto2/bronze/users/1774918922.266945.ca01ed0828.parquet")

# %%
df_users.printSchema()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- reputation: binary (nullable = true)
#  |-- creation_date: timestamp (nullable = true)
#  |-- display_name: binary (nullable = true)
#  |-- last_access_date: timestamp (nullable = true)
#  |-- about_me: binary (nullable = true)
#  |-- views: long (nullable = true)
#  |-- up_votes: long (nullable = true)
#  |-- down_votes: long (nullable = true)
#  |-- website_url: binary (nullable = true)
#  |-- location: binary (nullable = true)
#  |-- account_id: long (nullable = true)

# %%
df_users.limit(5).show()
# Out:
# +-------+----------+--------------------+--------------------+--------------------+--------+-----+--------+----------+-----------+-------------------+----------+
# |     id|reputation|       creation_date|        display_name|    last_access_date|about_me|views|up_votes|down_votes|website_url|           location|account_id|
# +-------+----------+--------------------+--------------------+--------------------+--------+-----+--------+----------+-----------+-------------------+----------+
# |2739130|      [31]|2013-09-02 08:30:...|[75 73 65 72 32 3...|2014-01-09 15:26:...|      []|    0|       0|         0|         []|                 []|   3248161|
# |2739131|      [31]|2013-09-02 08:30:...|[45 72 69 63 20 4...|2014-05-22 10:52:...|      []|    0|       0|         0|         []|                 []|   3248162|
# |2739132|[38 34 39]|2013-09-02 08:30:...| [45 6E 69 67 6D 61]|2024-03-22 06:05:...|      []|  153|      90|         3|         []|[4D 75 6D 62 61 69]|   3248163|
# ...

# %%
#Cambiar las columnas de hexadecimal a string
df_users = df_users.withColumn("display_name", col("display_name").cast("string"))
df_users = df_users.withColumn("location", col("location").cast("string"))
df_users = df_users.withColumn("about_me", col("about_me").cast("string"))
df_users = df_users.withColumn("website_url", col("website_url").cast("string"))
df_users = df_users.withColumn("reputation",col("reputation").cast("string").cast(IntegerType()))

# %%
df_users.show(5)
# Out:
# +-------+----------+--------------------+------------+--------------------+--------+-----+--------+----------+-----------+--------+----------+
# |     id|reputation|       creation_date|display_name|    last_access_date|about_me|views|up_votes|down_votes|website_url|location|account_id|
# +-------+----------+--------------------+------------+--------------------+--------+-----+--------+----------+-----------+--------+----------+
# |2739130|         1|2013-09-02 08:30:...| user2739130|2014-01-09 15:26:...|        |    0|       0|         0|           |        |   3248161|
# |2739131|         1|2013-09-02 08:30:...| Eric Andrén|2014-05-22 10:52:...|        |    0|       0|         0|           |        |   3248162|
# |2739132|       849|2013-09-02 08:30:...|      Enigma|2024-03-22 06:05:...|        |  153|      90|         3|           |  Mumbai|   3248163|
# ...

# %%
df_users.printSchema()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- reputation: integer (nullable = true)
#  |-- creation_date: timestamp (nullable = true)
#  |-- display_name: string (nullable = true)
#  |-- last_access_date: timestamp (nullable = true)
#  |-- about_me: string (nullable = true)
#  |-- views: long (nullable = true)
#  |-- up_votes: long (nullable = true)
#  |-- down_votes: long (nullable = true)
#  |-- website_url: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- account_id: long (nullable = true)

# %%
df_posts_2023 = spark.read.parquet("s3a://proyecto2/bronze/posts_2023/1774918638.6598768.c3741433cf.parquet")

# %%
df_posts_2023.printSchema()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- post_type_id: long (nullable = true)
#  |-- accepted_answer_id: long (nullable = true)
#  |-- creation_date: timestamp (nullable = true)
#  |-- score: long (nullable = true)
#  |-- view_count: long (nullable = true)
#  |-- body: binary (nullable = true)
#  |-- owner_user_id: long (nullable = true)
#  |-- owner_display_name: binary (nullable = true)
#  |-- last_editor_user_id: long (nullable = true)
#  |-- last_editor_display_name: binary (nullable = true)
#  |-- last_edit_date: timestamp (nullable = true)
#  |-- last_activity_date: timestamp (nullable = true)
#  |-- title: binary (nullable = true)
#  |-- tags: binary (nullable = true)
#  |-- answer_count: long (nullable = true)
#  |-- comment_count: long (nullable = true)
#  |-- favorite_count: long (nullable = true)
#  |-- content_license: binary (nullable = true)
#  |-- parent_id: binary (nullable = true)
#  |-- community_owned_date: timestamp (nullable = true)
# ...

# %%
df_posts_2023.show(5, truncate=False, vertical=True)
# Out:
# -RECORD 0-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
df_posts_2023 = df_posts_2023.withColumn("body", col("body").cast("string"))
df_posts_2023 = df_posts_2023.withColumn("title", col("title").cast("string"))
df_posts_2023 = df_posts_2023.withColumn("tags", col("tags").cast("string"))
df_posts_2023 = df_posts_2023.withColumn("content_license", col("content_license").cast("string"))
df_posts_2023 = df_posts_2023.withColumn("parent_id",col("parent_id").cast("string").cast(IntegerType()))

#Pasar el body a texto plano
df_posts_2023 = df_posts_2023.withColumn(
    "body",
    regexp_replace(col("body"), "<[^>]*>", "")
)
#Los tags se cambian a separar con , en vez de |
df_posts_2023 = df_posts_2023.withColumn(
    "tags",
    regexp_replace(col("tags"), r"\|", ",")
)

#Quitar las comas extras que se generó con ese cambio
df_posts_2023 = df_posts_2023.withColumn("tags",
    regexp_replace(
        trim(regexp_replace(col("tags"), r"\|", ",")),
        r"^,|,$",  
        ""          
    )
)

# %%
df_posts_2023.show(5, truncate=False, vertical=True)
# Out:
# -RECORD 0-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
df_posts_2024 = spark.read.parquet("s3a://proyecto2/bronze/posts_2024/1774918638.6598768.8cd45fd9b8.parquet")

# %%
df_posts_2024.printSchema()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- post_type_id: long (nullable = true)
#  |-- accepted_answer_id: long (nullable = true)
#  |-- creation_date: timestamp (nullable = true)
#  |-- score: long (nullable = true)
#  |-- view_count: long (nullable = true)
#  |-- body: binary (nullable = true)
#  |-- owner_user_id: long (nullable = true)
#  |-- owner_display_name: binary (nullable = true)
#  |-- last_editor_user_id: long (nullable = true)
#  |-- last_editor_display_name: binary (nullable = true)
#  |-- last_edit_date: timestamp (nullable = true)
#  |-- last_activity_date: timestamp (nullable = true)
#  |-- title: binary (nullable = true)
#  |-- tags: binary (nullable = true)
#  |-- answer_count: long (nullable = true)
#  |-- comment_count: long (nullable = true)
#  |-- favorite_count: long (nullable = true)
#  |-- content_license: binary (nullable = true)
#  |-- parent_id: binary (nullable = true)
#  |-- community_owned_date: timestamp (nullable = true)
# ...

# %%
df_posts_2024 = df_posts_2024.withColumn("body", col("body").cast("string"))
df_posts_2024 = df_posts_2024.withColumn("title", col("title").cast("string"))
df_posts_2024 = df_posts_2024.withColumn("tags", col("tags").cast("string"))
df_posts_2024 = df_posts_2024.withColumn("content_license", col("content_license").cast("string"))
df_posts_2024 = df_posts_2024.withColumn("parent_id",col("parent_id").cast("string").cast(IntegerType()))

#Pasar el body a texto plano
df_posts_2024 = df_posts_2024.withColumn(
    "body",
    regexp_replace(col("body"), "<[^>]*>", "")
)
#Los tags se cambian a separar con , en vez de |
df_posts_2024 = df_posts_2024.withColumn(
    "tags",
    regexp_replace(col("tags"), r"\|", ",")
)

#Quitar las comas extras que se generó con ese cambio
df_posts_2024 = df_posts_2024.withColumn("tags",
    regexp_replace(
        trim(regexp_replace(col("tags"), r"\|", ",")),
        r"^,|,$",  
        ""          
    )
)

# %%
df_posts_2024.show(5, truncate=False, vertical=True)
# Out:
# -RECORD 0-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
df_comments_2023 = spark.read.parquet("s3a://proyecto2/bronze/comments_2023/1774918555.7865863.75036f1404.parquet")
df_comments_2023.printSchema()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- post_id: long (nullable = true)
#  |-- score: long (nullable = true)
#  |-- text: binary (nullable = true)
#  |-- creation_date: timestamp (nullable = true)
#  |-- user_id: long (nullable = true)
#  |-- user_display_name: binary (nullable = true)

# %%
df_comments_2023 = df_comments_2023.withColumn("text", col("text").cast("string"))
df_comments_2023 = df_comments_2023.withColumn("user_display_name", col("user_display_name").cast("string"))

# %%
df_comments_2023.show(5, truncate=False, vertical=True)
# Out:
# -RECORD 0----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  id                | 136736877
#  post_id           | 5254192
#  score             | 1
#  text              | If your name isn't "Abhishek Tanwar" on Medium, it appears that someone has appropriated your answer and predominantly copied it on Medium. You can view the replicated content here: https://medium.com/@abhishektanwar9596/what-is-the-difference-between-map-and-each-in-ruby-1f2fbb5d5842
#  creation_date     | 2023-11-28 07:01:46.357
#  user_id           | 2008111
#  user_display_name |
# ...

# %%
df_comments_2024 = spark.read.parquet("s3a://proyecto2/bronze/comments_2024/1774918555.7865863.2d07f1c736.parquet")
df_comments_2024.printSchema()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- post_id: long (nullable = true)
#  |-- score: long (nullable = true)
#  |-- text: binary (nullable = true)
#  |-- creation_date: timestamp (nullable = true)
#  |-- user_id: long (nullable = true)
#  |-- user_display_name: binary (nullable = true)

# %%
df_comments_2024 = df_comments_2024.withColumn("text", col("text").cast("string"))
df_comments_2024 = df_comments_2024.withColumn("user_display_name", col("user_display_name").cast("string"))

# %%
df_comments_2024.show(5, truncate=False, vertical=True)
# Out:
# -RECORD 0--------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  id                | 137602483
#  post_id           | 5250374
#  score             | 0
#  text              | This seems like a potential [xy problen](https://meta.stackexchange.com/questions/66377/what-is-the-xy-problem/233676#233676). Why would you want to do this?
#  creation_date     | 2024-02-24 16:51:39.103
#  user_id           | 6243352
#  user_display_name |
# -RECORD 1--------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  id                | 137534262
#  post_id           | 5296860
#  score             | 0
#  text              | Link no longer works...
#  creation_date     | 2024-02-17 22:19:24.033
#  user_id           | 1516044
#  user_display_name |
# ...

# %%
cols = df_posts_2023.columns  # todas las columnas

df_posts = df_posts_2023.alias("a").join(
    df_posts_2024.alias("b"),
    on="id",
    how="outer"
).select([
    coalesce(f"b.{c}", f"a.{c}").alias(c) if c != 'id' else coalesce(f"b.id", f"a.id").alias('id')
    for c in cols
]).repartition(200)

# %%
df_posts_2023.count()
# Out:
# 2001772

# %%
df_posts_2024.count()
# Out:
# 385533

# %%
df_posts.count()
# Out:
# 2387305

# %%
df_posts.printSchema()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- post_type_id: long (nullable = true)
#  |-- accepted_answer_id: long (nullable = true)
#  |-- creation_date: timestamp (nullable = true)
#  |-- score: long (nullable = true)
#  |-- view_count: long (nullable = true)
#  |-- body: string (nullable = true)
#  |-- owner_user_id: long (nullable = true)
#  |-- owner_display_name: binary (nullable = true)
#  |-- last_editor_user_id: long (nullable = true)
#  |-- last_editor_display_name: binary (nullable = true)
#  |-- last_edit_date: timestamp (nullable = true)
#  |-- last_activity_date: timestamp (nullable = true)
#  |-- title: string (nullable = true)
#  |-- tags: string (nullable = true)
#  |-- answer_count: long (nullable = true)
#  |-- comment_count: long (nullable = true)
#  |-- favorite_count: long (nullable = true)
#  |-- content_license: string (nullable = true)
#  |-- parent_id: integer (nullable = true)
#  |-- community_owned_date: timestamp (nullable = true)
# ...

# %%
cols = df_comments_2023.columns  # todas las columnas

df_comments = df_comments_2023.alias("a").join(
    df_comments_2024.alias("b"),
    on="id",
    how="outer"
).select([
    coalesce(f"b.{c}", f"a.{c}").alias(c) if c != 'id' else coalesce(f"b.id", f"a.id").alias('id')
    for c in cols
]).repartition(200)

# %%
df_comments_2023.count()
# Out:
# 2950672

# %%
df_comments_2024.count()
# Out:
# 580920

# %%
df_comments_2023.count() + df_comments_2024.count()
# Out:
# 3531592

# %%
df_comments.count()
# Out:
# 3531592

# %%
#y = df_posts_2023.filter(df_posts_2023.id == 76471267)

# %%
#y.show(5)

# %%
#CARGAR A MINIO EN FORMATO ICEBERG (CON MERGE) (Unir las 2 tablas anuales en 1 sola, agregando columna de fecha de subida y con metodo upsert)

# %%
query = "CREATE NAMESPACE IF NOT EXISTS nessie.silver" 
spark._jsparkSession.sql(query)
# Out:
# JavaObject id=o410

# %%
from pyspark.sql.functions import hash, col #Metodo upsert, manual porque.... aja. es lo unico que sirve

if not spark.catalog.tableExists('nessie.silver.posts_'):
    df_posts.limit(0).writeTo('nessie.silver.posts_') \
        .using("iceberg") \
        .tableProperty("format-version", "2") \
        .create()

num_batches = 20 
    
df_batched = df_posts.withColumn(
    "batch_id",
    (hash("id") % num_batches)
)


for i in range(num_batches):
    print(f'Procesando batch: {i}')
    batch_df = df_batched.filter(col("batch_id") == i).drop("batch_id")
    
    # IDs del batch actual
    batch_ids = batch_df.select("id")
    
    # Borrar registros existentes que van a ser actualizados
    batch_ids.createOrReplaceTempView("batch_ids_staging")
    spark.sql("""
        DELETE FROM nessie.silver.posts_
        WHERE id IN (SELECT id FROM batch_ids_staging)
    """)
    
    # Insertar todos (nuevos + actualizados)
    batch_df.writeTo("nessie.silver.posts_").append()
    
    print(f'Batch {i} completado')
# Out:
# Procesando batch: 0

# %%
num_batches = 20 
from pyspark.sql.functions import hash as spark_hash, col

df_batched = df_posts.withColumn(
    "batch_id",
    spark_hash(col("id")) % num_batches
)

if not spark.catalog.tableExists('nessie.silver.posts_'):
    df_posts.limit(0).writeTo('nessie.silver.posts_') \
        .using("iceberg") \
        .tableProperty("format-version", "2") \
        .create()

for i in range(num_batches):
    print('Procesando batch: ', i)
    batch_df = df_batched.filter(col("batch_id") == i).drop("batch_id")

    batch_df.createOrReplaceTempView("staging")

    spark.sql("""
        MERGE INTO nessie.silver.posts_ t
        USING staging s
        ON t.id = s.id
        WHEN MATCHED THEN UPDATE SET *
        WHEN NOT MATCHED THEN INSERT *
    """)
# Out:
# Procesando batch:  0
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/py4j/clientserver.py", line 516, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
# ...

# %%
num_batches = 10

df_batched = df_posts.withColumn(
    "batch_id",
    (hash("id") % num_batches)
)

if not spark.catalog.tableExists('nessie.silver.posts_'):
    df_posts.limit(0).writeTo('nessie.silver.posts_') \
        .using("iceberg") \
        .tableProperty("format-version", "2") \
        .create()

for i in range(num_batches):
    print('Procesando batch: ', i)
    batch_df = df_batched.filter(col("batch_id") == i).drop("batch_id") #Batching porque spark es mas debil que yo

    batch_df.createOrReplaceTempView("staging")

    query = """
    MERGE INTO nessie.silver.posts_ t
    USING staging s
    ON t.id = s.id
    WHEN MATCHED THEN UPDATE SET *
    WHEN NOT MATCHED THEN INSERT *
    """
    
    spark.sql(query)
# Out:
# Procesando batch:  0
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/py4j/clientserver.py", line 516, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
# ...
